# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.
#
# In the world of data science, a variety of tools and technologies come together to form an ecosystem that enables data analysis, visualization, machine learning, and more. This ecosystem empowers data scientists to derive insights, build models, and make data-driven decisions efficiently.

# %% [markdown]
# ### Popular Data Science Languages
#
# Some of the popular languages that Data Scientists use are:
#
# 1. **Python** - Known for its simplicity and a rich ecosystem of libraries like Pandas, NumPy, and Scikit-learn.
# 2. **R** - A powerful language for statistical analysis and data visualization.
# 3. **SQL** - Essential for querying and managing structured data in databases.
# 4. **Julia** - A high-performance language for numerical computing.
# 5. **Java** - Often used in big data frameworks like Hadoop and Spark.

# %% [markdown]
# ### Commonly Used Data Science Libraries
#
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. **Pandas** - For data manipulation and analysis.
# 2. **NumPy** - For numerical computations and handling multidimensional arrays.
# 3. **Matplotlib** - For creating static, animated, and interactive visualizations.
# 4. **Scikit-learn** - For machine learning and predictive modeling.
# 5. **TensorFlow** - For building and training deep learning models.
# 6. **Seaborn** - For statistical data visualization.

# %% [markdown]
# ### Data Science Tools
#
# | Data Science Tools           |
# |-------------------------------|
# | Jupyter Notebook             |
# | RStudio                      |
# | Apache Zeppelin              |

# %% [markdown]
# ### Arithmetic Expression Examples
#
# Below are a few examples of evaluating arithmetic expressions in Python:
#
# - **Addition**: `3 + 5` evaluates to `8`.
# - **Subtraction**: `10 - 4` evaluates to `6`.
# - **Multiplication**: `7 * 3` evaluates to `21`.
# - **Division**: `16 / 4` evaluates to `4.0`.
# - **Exponentiation**: `2 ** 3` evaluates to `8`.
# - **Modulo**: `10 % 3` evaluates to `1`.

# %%
# This is a simple arithmetic expression to multiply then add integers
(3 * 4) + 5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ### Objectives:
#
# **Objectives:**
#
# - List popular languages for Data Science.
# - Identify commonly used libraries in Data Science.
# - Explore development environment tools for Data Science.
# - Demonstrate examples of arithmetic expressions in Python.
# - Convert time units such as minutes to hours using Python.

# %% [markdown]
# ## Author
#
# Rahmah Anggita Fitri
